# %%
import json 
import pandas as pd 

df = pd.read_json("data.json")

def flatten(a):
    return a[0]

# %%
A = df['ratings'].apply(pd.Series)
B = df['reviews'].apply(test).apply(pd.Series)

# %%
amazon_df = pd.concat([df.drop(['ratings', 'reviews'],axis=1),
           A,B],axis = 1)

# %%
amazon_df.drop(['name','price'],axis=1)
# Out:
#                                                   url 5 star 4 star 3 star  \
# 0   https://www.amazon.com/product-reviews/B01DFKC...    67%    14%     8%
# 1   https://www.amazon.com/product-reviews/B01DFKC...    67%    14%     8%
# 2   https://www.amazon.com/product-reviews/B01DFKC...    67%    14%     8%
# 3   https://www.amazon.com/product-reviews/B01DFKC...    67%    14%     8%
# 4   https://www.amazon.com/product-reviews/B01DFKC...    67%    14%     8%
# 5   https://www.amazon.com/product-reviews/B0792KT...    79%    11%     4%
# 6   https://www.amazon.com/product-reviews/B0792KT...    79%    11%     4%
# 7   https://www.amazon.com/product-reviews/B0792KT...    79%    11%     4%
# 8   https://www.amazon.com/product-reviews/B0792KT...    79%    11%     4%
# 9   https://www.amazon.com/product-reviews/B0792KT...    79%    11%     4%
# 10  https://www.amazon.com/product-reviews/B06XCM9...    73%    13%     6%
# 11  https://www.amazon.com/product-reviews/B06XCM9...    73%    13%     6%
# 12  https://www.amazon.com/product-reviews/B06XCM9...    73%    13%     6%
# 13  https://www.amazon.com/product-reviews/B06XCM9...    73%    13%     6%
# 14  https://www.amazon.com/product-reviews/B06XCM9...    73%    13%     6%
#
#    2 star 1 star review_comment_count review_helpful  \
# 0      4%     7%                    6            411
# 1      4%     7%                    1             37
# 2      4%     7%                    2          5,768
# 3      4%     7%                    5          2,949
# 4      4%     7%                    1             32
# 5      2%     4%                    2          1,737
# 6      2%     4%                    1             82
# 7      2%     4%                    C             37
# 8      2%     4%                    2             21
# 9      2%     4%                    C             15
# 10     3%     5%                    8            837
# 11     3%     5%                    5          2,691
# 12     3%     5%                    1             15
# 13     3%     5%                    C             18
# 14     3%     5%                    C              5
#
#                                           review_text review_posted_date  \
# 0   So, I fired Siri today. I'm not sure she under...        24 Feb 2018
# 1   When I first got the Echo Dot, my mind was rac...        22 Oct 2017
# 2   Thanks for taking the time to read this review...        24 Oct 2016
# 3   NEEDS security! Anyone in range of this things...        14 Feb 2017
# 4   I got some smart plugs so that I could turn on...        20 Jul 2018
# 5   Sound quality is the best I've heard on a spea...        15 Oct 2018
# 6   I'm forced to use the online Alexa app because...        02 Nov 2018
# 7   Horrible and invasive. Total invasion of priva...        12 Nov 2018
# 8   I bought this to replace my old Echo Dot gen 2...        18 Oct 2018
# 9   This thing is awesome. It sounds so good. This...        16 Oct 2018
# 10  I got some smart plugs so that I could turn on...        20 Jul 2018
# 11  So it’s been an interesting first few weeks wi...        02 Nov 2017
# 12  Welcome to the Amazon bait and switch. It’s ca...        02 Oct 2018
# 13  After struggling and a Little Help from custom...        24 Mar 2018
# 14  Alexa is fun to ask to play music and other no...        11 Oct 2018
#
#                                         review_header review_rating  \
# 0                                       Divorced Siri          5.0
# 1   Prepare to repeat yourself and wake up your fa...          2.0
# 2   A huge improvement over last years release and...          5.0
# 3                                  NEEDS SECURITY!!!!          1.0
# 4                       AWESOME FOR SENIOR CITIZENS!!          5.0
# 5   Better than 2nd Gen! ***HERE'S HOW TO HELP WIT...          5.0
# 6             Don't rely on it for anything important          1.0
# 7   Throw any privacy ou the window if you use thi...          1.0
# 8                                             Muffled          1.0
# 9                   Great smart speaker for the price          5.0
# 10                                    AMAZING SOUND!!          5.0
# 11  Sound quality has been improved again! 3rd tim...          5.0
# 12  Removed my most important feature after I boug...          1.0
# 13  Dont buy unless you plan on paying extra for s...          1.0
# 14                    Mostly a Novelty but Unreliable          2.0
#
#           review_author
# 0                Simone
# 1              Eric Lai
# 2                 RaVen
# 3               william
# 4   Sherry the Dog Lady
# 5                 Peter
# 6               Marc D.
# 7                    rs
# 8             Taylor H.
# 9                 Aiden
# 10  Sherry the Dog Lady
# 11       B. FromSeattle
# 12                Mac75
# 13                 Mike
# 14             Oak tree
